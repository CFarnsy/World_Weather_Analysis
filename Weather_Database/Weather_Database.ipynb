# %% [markdown]
# ## Deliverable 1. Retrieve Weather Data.

# %%
# Add dependencies
# Import Pandas
import pandas as pd
# Import matplotlib
import matplotlib.pyplot as plt
#Import Numpy
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the requests library.
import requests
# Import the time library and datetime module from the datetime library.
import time 
from datetime import datetime
# Import the API key.
from config import weather_api_key, g_key
# Import the random module.
import random
# Import timeit - This test how long a piece of code or function takes to 
# run (complete).
import timeit

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 774

# %%
# Starting URL for Weather Map API Call. 
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | nikolskoye
# Processing Record 4 of Set 1 | keffi
# Processing Record 5 of Set 1 | luderitz
# Processing Record 6 of Set 1 | cherskiy
# Processing Record 7 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 1 | yar-sale
# Processing Record 9 of Set 1 | cuajinicuilapa
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | la baule-escoublac
# Processing Record 12 of Set 1 | dikson
# Processing Record 13 of Set 1 | sao joao da barra
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | shubarshi
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | mount gambier
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | tasiilaq
# Processing Record 20 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 1 | castro
# Processing Record 22 of Set 1 | balabac
# Processing Record 23 of Set 1 | longyearbyen
# Processing Record 24 of Set 1 | half moon bay
# Processing Record 25 of Set 1 | souillac
# Processing Record 26 of Set 1 | kaitangata
# Processing Record 27 of Set 1 | pringsewu
# Processing Record 28 of Set 1 | puerto ayora
# Processing Record 29 of Set 1 | hobart
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | qaanaaq
# Processing Record 32 of Set 1 | carnarvon
# Processing Record 33 of Set 1 | georgetown
# Processing Record 34 of Set 1 | rikitea
# Processing Record 35 of Set 1 | esperance
# Processing Record 36 of Set 1 | kamenka
# Processing Record 37 of Set 1 | shangzhi
# Processing Record 38 of Set 1 | nouadhibou
# Processing Record 39 of Set 1 | santa isabel do rio negro
# Processing Record 40 of Set 1 | vila franca do campo
# Processing Record 41 of Set 1 | meulaboh
# Processing Record 42 of Set 1 | barrow
# Processing Record 43 of Set 1 | koumac
# Processing Record 44 of Set 1 | kapaa
# Processing Record 45 of Set 1 | port blair
# Processing Record 46 of Set 1 | olovo
# Processing Record 47 of Set 1 | ajdabiya
# Processing Record 48 of Set 1 | batemans bay
# Processing Record 49 of Set 1 | ola
# Processing Record 50 of Set 1 | cape town
# Processing Record 1 of Set 2 | wuda
# Processing Record 2 of Set 2 | torbay
# Processing Record 3 of Set 2 | roald
# Processing Record 4 of Set 2 | jamestown
# Processing Record 5 of Set 2 | karauzyak
# City not found. Skipping...
# Processing Record 6 of Set 2 | fukuma
# Processing Record 7 of Set 2 | atuona
# Processing Record 8 of Set 2 | port elizabeth
# Processing Record 9 of Set 2 | lupiro
# Processing Record 10 of Set 2 | hervey bay
# Processing Record 11 of Set 2 | samarai
# Processing Record 12 of Set 2 | berlevag
# Processing Record 13 of Set 2 | saint-prosper
# Processing Record 14 of Set 2 | lorengau
# Processing Record 15 of Set 2 | bredasdorp
# Processing Record 16 of Set 2 | namatanai
# Processing Record 17 of Set 2 | san pedro
# Processing Record 18 of Set 2 | avarua
# Processing Record 19 of Set 2 | ust-nera
# Processing Record 20 of Set 2 | tahlequah
# Processing Record 21 of Set 2 | yulara
# Processing Record 22 of Set 2 | faanui
# Processing Record 23 of Set 2 | ustrzyki dolne
# Processing Record 24 of Set 2 | hofn
# Processing Record 25 of Set 2 | provideniya
# Processing Record 26 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 2 | muzhi
# Processing Record 28 of Set 2 | sao filipe
# Processing Record 29 of Set 2 | kavieng
# Processing Record 30 of Set 2 | caborca
# Processing Record 31 of Set 2 | bhatkal
# Processing Record 32 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 2 | najran
# Processing Record 34 of Set 2 | yellowknife
# Processing Record 35 of Set 2 | plettenberg bay
# Processing Record 36 of Set 2 | tuburan
# Processing Record 37 of Set 2 | batagay-alyta
# Processing Record 38 of Set 2 | yarmouth
# Processing Record 39 of Set 2 | mar del plata
# Processing Record 40 of Set 2 | port augusta
# Processing Record 41 of Set 2 | muros
# Processing Record 42 of Set 2 | laguna
# Processing Record 43 of Set 2 | norman wells
# Processing Record 44 of Set 2 | colonial heights
# Processing Record 45 of Set 2 | vaini
# Processing Record 46 of Set 2 | havre-saint-pierre
# Processing Record 47 of Set 2 | agadez
# Processing Record 48 of Set 2 | padilla
# Processing Record 49 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 50 of Set 2 | hilo
# Processing Record 1 of Set 3 | lagoa
# Processing Record 2 of Set 3 | thompson
# Processing Record 3 of Set 3 | butaritari
# Processing Record 4 of Set 3 | lazi
# Processing Record 5 of Set 3 | vila velha
# Processing Record 6 of Set 3 | hobyo
# Processing Record 7 of Set 3 | mahebourg
# Processing Record 8 of Set 3 | ye
# City not found. Skipping...
# Processing Record 9 of Set 3 | severo-yeniseyskiy
# Processing Record 10 of Set 3 | kloulklubed
# Processing Record 11 of Set 3 | caruray
# Processing Record 12 of Set 3 | tuktoyaktuk
# Processing Record 13 of Set 3 | belaya gora
# Processing Record 14 of Set 3 | puerto lopez
# Processing Record 15 of Set 3 | broken hill
# Processing Record 16 of Set 3 | danville
# Processing Record 17 of Set 3 | pitimbu
# Processing Record 18 of Set 3 | coihaique
# Processing Record 19 of Set 3 | lebedinyy
# Processing Record 20 of Set 3 | portland
# Processing Record 21 of Set 3 | larsnes
# Processing Record 22 of Set 3 | pilar
# Processing Record 23 of Set 3 | port alfred
# Processing Record 24 of Set 3 | urdzhar
# City not found. Skipping...
# Processing Record 25 of Set 3 | mayo
# Processing Record 26 of Set 3 | san felipe
# Processing Record 27 of Set 3 | kruisfontein
# Processing Record 28 of Set 3 | narsaq
# Processing Record 29 of Set 3 | victoria
# Processing Record 30 of Set 3 | san-pedro
# Processing Record 31 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 3 | nhulunbuy
# Processing Record 34 of Set 3 | sorland
# Processing Record 35 of Set 3 | atar
# Processing Record 36 of Set 3 | faya
# Processing Record 37 of Set 3 | sinnamary
# Processing Record 38 of Set 3 | mega
# Processing Record 39 of Set 3 | yinchuan
# Processing Record 40 of Set 3 | tiksi
# Processing Record 41 of Set 3 | lavrentiya
# Processing Record 42 of Set 3 | olinda
# Processing Record 43 of Set 3 | sai buri
# Processing Record 44 of Set 3 | angol
# Processing Record 45 of Set 3 | ketchikan
# Processing Record 46 of Set 3 | kitami
# Processing Record 47 of Set 3 | khovu-aksy
# Processing Record 48 of Set 3 | lompoc
# Processing Record 49 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 50 of Set 3 | lebu
# Processing Record 1 of Set 4 | richmond
# Processing Record 2 of Set 4 | klaksvik
# Processing Record 3 of Set 4 | hithadhoo
# Processing Record 4 of Set 4 | aden
# Processing Record 5 of Set 4 | grenville
# Processing Record 6 of Set 4 | ilulissat
# Processing Record 7 of Set 4 | manokwari
# Processing Record 8 of Set 4 | shu
# Processing Record 9 of Set 4 | qaqortoq
# Processing Record 10 of Set 4 | hami
# Processing Record 11 of Set 4 | labutta
# City not found. Skipping...
# Processing Record 12 of Set 4 | sebrovo
# Processing Record 13 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 4 | kieta
# Processing Record 16 of Set 4 | gulu
# Processing Record 17 of Set 4 | maragogi
# Processing Record 18 of Set 4 | rio grande
# Processing Record 19 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 20 of Set 4 | lebork
# Processing Record 21 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 4 | elat
# Processing Record 23 of Set 4 | odoyev
# Processing Record 24 of Set 4 | newala
# Processing Record 25 of Set 4 | owo
# Processing Record 26 of Set 4 | ribeira grande
# Processing Record 27 of Set 4 | saint paul
# Processing Record 28 of Set 4 | sterling
# Processing Record 29 of Set 4 | naze
# Processing Record 30 of Set 4 | kodiak
# Processing Record 31 of Set 4 | bethel
# Processing Record 32 of Set 4 | kedougou
# Processing Record 33 of Set 4 | chuy
# Processing Record 34 of Set 4 | wajir
# Processing Record 35 of Set 4 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 36 of Set 4 | kouango
# Processing Record 37 of Set 4 | necochea
# Processing Record 38 of Set 4 | mount isa
# Processing Record 39 of Set 4 | sicuani
# Processing Record 40 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 41 of Set 4 | fortuna
# Processing Record 42 of Set 4 | cidreira
# Processing Record 43 of Set 4 | payo
# Processing Record 44 of Set 4 | podor
# Processing Record 45 of Set 4 | bonthe
# Processing Record 46 of Set 4 | kahului
# Processing Record 47 of Set 4 | aklavik
# Processing Record 48 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 4 | komsomolskiy
# Processing Record 50 of Set 4 | huilong
# Processing Record 1 of Set 5 | constitucion
# Processing Record 2 of Set 5 | phangnga
# Processing Record 3 of Set 5 | touros
# Processing Record 4 of Set 5 | nago
# Processing Record 5 of Set 5 | chapais
# Processing Record 6 of Set 5 | quelimane
# Processing Record 7 of Set 5 | seddon
# Processing Record 8 of Set 5 | katsuura
# Processing Record 9 of Set 5 | redlands
# Processing Record 10 of Set 5 | beira
# Processing Record 11 of Set 5 | bonawon
# Processing Record 12 of Set 5 | iqaluit
# Processing Record 13 of Set 5 | vestmannaeyjar
# Processing Record 14 of Set 5 | mandalgovi
# Processing Record 15 of Set 5 | saint george
# Processing Record 16 of Set 5 | tura
# Processing Record 17 of Set 5 | ulagan
# Processing Record 18 of Set 5 | muli
# Processing Record 19 of Set 5 | lalibela
# Processing Record 20 of Set 5 | aykhal
# Processing Record 21 of Set 5 | san policarpo
# Processing Record 22 of Set 5 | airai
# Processing Record 23 of Set 5 | mulchen
# Processing Record 24 of Set 5 | ibaiti
# Processing Record 25 of Set 5 | sebring
# Processing Record 26 of Set 5 | marsh harbour
# Processing Record 27 of Set 5 | paamiut
# Processing Record 28 of Set 5 | port hardy
# Processing Record 29 of Set 5 | vilhena
# Processing Record 30 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 31 of Set 5 | saskylakh
# Processing Record 32 of Set 5 | marzuq
# Processing Record 33 of Set 5 | santa rosa
# Processing Record 34 of Set 5 | east london
# Processing Record 35 of Set 5 | severo-kurilsk
# Processing Record 36 of Set 5 | leningradskiy
# Processing Record 37 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 38 of Set 5 | pisco
# Processing Record 39 of Set 5 | hellvik
# Processing Record 40 of Set 5 | ust-maya
# Processing Record 41 of Set 5 | namibe
# Processing Record 42 of Set 5 | filingue
# Processing Record 43 of Set 5 | arraial do cabo
# Processing Record 44 of Set 5 | cayenne
# Processing Record 45 of Set 5 | alofi
# Processing Record 46 of Set 5 | dunedin
# Processing Record 47 of Set 5 | richards bay
# Processing Record 48 of Set 5 | korla
# Processing Record 49 of Set 5 | bolsheustikinskoye
# City not found. Skipping...
# Processing Record 50 of Set 5 | srednekolymsk
# Processing Record 1 of Set 6 | turukhansk
# Processing Record 2 of Set 6 | wajima
# Processing Record 3 of Set 6 | treinta y tres
# Processing Record 4 of Set 6 | zarubino
# Processing Record 5 of Set 6 | okhotsk
# Processing Record 6 of Set 6 | hamilton
# Processing Record 7 of Set 6 | jalu
# Processing Record 8 of Set 6 | seabrook
# Processing Record 9 of Set 6 | bambous virieux
# Processing Record 10 of Set 6 | salalah
# Processing Record 11 of Set 6 | saint-philippe
# Processing Record 12 of Set 6 | savannakhet
# Processing Record 13 of Set 6 | kinsale
# Processing Record 14 of Set 6 | biak
# Processing Record 15 of Set 6 | marsa matruh
# Processing Record 16 of Set 6 | geraldton
# Processing Record 17 of Set 6 | guerrero negro
# Processing Record 18 of Set 6 | mahadday weyne
# City not found. Skipping...
# Processing Record 19 of Set 6 | konstantinovo
# Processing Record 20 of Set 6 | cabo san lucas
# Processing Record 21 of Set 6 | ginir
# Processing Record 22 of Set 6 | gumdag
# Processing Record 23 of Set 6 | awjilah
# Processing Record 24 of Set 6 | dourados
# Processing Record 25 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 6 | sakakah
# Processing Record 27 of Set 6 | saint-joseph
# Processing Record 28 of Set 6 | beyneu
# Processing Record 29 of Set 6 | vianopolis
# Processing Record 30 of Set 6 | beipiao
# Processing Record 31 of Set 6 | dingle
# Processing Record 32 of Set 6 | chokurdakh
# Processing Record 33 of Set 6 | millinocket
# Processing Record 34 of Set 6 | rosetta
# Processing Record 35 of Set 6 | new norfolk
# Processing Record 36 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 6 | oda
# Processing Record 38 of Set 6 | malanje
# Processing Record 39 of Set 6 | bubaque
# Processing Record 40 of Set 6 | merauke
# Processing Record 41 of Set 6 | chiredzi
# Processing Record 42 of Set 6 | naftah
# City not found. Skipping...
# Processing Record 43 of Set 6 | manta
# Processing Record 44 of Set 6 | paramonga
# Processing Record 45 of Set 6 | pauini
# Processing Record 46 of Set 6 | miles city
# Processing Record 47 of Set 6 | rancho san diego
# Processing Record 48 of Set 6 | omboue
# Processing Record 49 of Set 6 | sitka
# Processing Record 50 of Set 6 | te anau
# Processing Record 1 of Set 7 | manzil jamil
# City not found. Skipping...
# Processing Record 2 of Set 7 | rocha
# Processing Record 3 of Set 7 | asbe teferi
# Processing Record 4 of Set 7 | megion
# Processing Record 5 of Set 7 | tessalit
# Processing Record 6 of Set 7 | araouane
# Processing Record 7 of Set 7 | olafsvik
# Processing Record 8 of Set 7 | mackay
# Processing Record 9 of Set 7 | bay roberts
# Processing Record 10 of Set 7 | cap malheureux
# Processing Record 11 of Set 7 | awbari
# Processing Record 12 of Set 7 | aswan
# Processing Record 13 of Set 7 | krasnogorskoye
# Processing Record 14 of Set 7 | vostok
# Processing Record 15 of Set 7 | jumla
# Processing Record 16 of Set 7 | jagdalpur
# Processing Record 17 of Set 7 | camacha
# Processing Record 18 of Set 7 | bafoulabe
# Processing Record 19 of Set 7 | tchibanga
# Processing Record 20 of Set 7 | jurado
# Processing Record 21 of Set 7 | blyth
# Processing Record 22 of Set 7 | yakeshi
# Processing Record 23 of Set 7 | neryungri
# Processing Record 24 of Set 7 | codrington
# Processing Record 25 of Set 7 | amberley
# Processing Record 26 of Set 7 | arkhangelos
# City not found. Skipping...
# Processing Record 27 of Set 7 | amapa
# Processing Record 28 of Set 7 | stanghelle
# Processing Record 29 of Set 7 | lata
# Processing Record 30 of Set 7 | lasa
# Processing Record 31 of Set 7 | gualaquiza
# Processing Record 32 of Set 7 | nipawin
# Processing Record 33 of Set 7 | mena
# Processing Record 34 of Set 7 | coquimbo
# Processing Record 35 of Set 7 | huatusco
# Processing Record 36 of Set 7 | havoysund
# Processing Record 37 of Set 7 | yerbogachen
# Processing Record 38 of Set 7 | linxia
# Processing Record 39 of Set 7 | kijang
# Processing Record 40 of Set 7 | dutse
# Processing Record 41 of Set 7 | krasnoselkup
# Processing Record 42 of Set 7 | porto novo
# Processing Record 43 of Set 7 | banda aceh
# Processing Record 44 of Set 7 | maltahohe
# Processing Record 45 of Set 7 | pangnirtung
# Processing Record 46 of Set 7 | tarauaca
# Processing Record 47 of Set 7 | manacapuru
# Processing Record 48 of Set 7 | formoso do araguaia
# City not found. Skipping...
# Processing Record 49 of Set 7 | lavumisa
# Processing Record 50 of Set 7 | oranjestad
# Processing Record 1 of Set 8 | mangai
# Processing Record 2 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 8 | pozo colorado
# Processing Record 4 of Set 8 | natal
# Processing Record 5 of Set 8 | edson
# Processing Record 6 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 8 | horqueta
# Processing Record 8 of Set 8 | goure
# Processing Record 9 of Set 8 | kropachevo
# Processing Record 10 of Set 8 | bambanglipuro
# Processing Record 11 of Set 8 | suozhen
# Processing Record 12 of Set 8 | taiyuan
# Processing Record 13 of Set 8 | north platte
# Processing Record 14 of Set 8 | coyah
# Processing Record 15 of Set 8 | hokitika
# Processing Record 16 of Set 8 | pevek
# Processing Record 17 of Set 8 | riyadh
# Processing Record 18 of Set 8 | hatillo
# Processing Record 19 of Set 8 | zachagansk
# City not found. Skipping...
# Processing Record 20 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 21 of Set 8 | aloleng
# Processing Record 22 of Set 8 | sao pedro do piaui
# Processing Record 23 of Set 8 | vardo
# Processing Record 24 of Set 8 | honiara
# Processing Record 25 of Set 8 | tazovskiy
# Processing Record 26 of Set 8 | itarema
# Processing Record 27 of Set 8 | kurchum
# Processing Record 28 of Set 8 | mocuba
# Processing Record 29 of Set 8 | hurricane
# Processing Record 30 of Set 8 | neiafu
# Processing Record 31 of Set 8 | port lincoln
# Processing Record 32 of Set 8 | saint-pierre
# Processing Record 33 of Set 8 | raudeberg
# Processing Record 34 of Set 8 | monterey
# Processing Record 35 of Set 8 | pangoa
# Processing Record 36 of Set 8 | safaga
# Processing Record 37 of Set 8 | buraydah
# Processing Record 38 of Set 8 | chizhou
# Processing Record 39 of Set 8 | florencia
# Processing Record 40 of Set 8 | ancud
# Processing Record 41 of Set 8 | rio gallegos
# Processing Record 42 of Set 8 | padang
# Processing Record 43 of Set 8 | teya
# Processing Record 44 of Set 8 | komsomolskoye
# Processing Record 45 of Set 8 | bengkulu
# Processing Record 46 of Set 8 | mehamn
# Processing Record 47 of Set 8 | peniche
# Processing Record 48 of Set 8 | dubasari
# Processing Record 49 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 50 of Set 8 | rudnogorsk
# Processing Record 1 of Set 9 | kudahuvadhoo
# Processing Record 2 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 9 | port-cartier
# Processing Record 4 of Set 9 | vammala
# Processing Record 5 of Set 9 | ingham
# Processing Record 6 of Set 9 | asfi
# Processing Record 7 of Set 9 | maneadero
# Processing Record 8 of Set 9 | yarada
# Processing Record 9 of Set 9 | hovd
# Processing Record 10 of Set 9 | mitsamiouli
# Processing Record 11 of Set 9 | copperas cove
# Processing Record 12 of Set 9 | marawi
# Processing Record 13 of Set 9 | pangkalanbuun
# Processing Record 14 of Set 9 | luce
# Processing Record 15 of Set 9 | san quintin
# Processing Record 16 of Set 9 | petropavlovka
# Processing Record 17 of Set 9 | hambantota
# Processing Record 18 of Set 9 | saldanha
# Processing Record 19 of Set 9 | pangai
# Processing Record 20 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 21 of Set 9 | melfi
# Processing Record 22 of Set 9 | klungkung
# Processing Record 23 of Set 9 | berbera
# Processing Record 24 of Set 9 | znamenskoye
# Processing Record 25 of Set 9 | gyanpur
# Processing Record 26 of Set 9 | nokaneng
# Processing Record 27 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 9 | la ronge
# Processing Record 29 of Set 9 | viedma
# Processing Record 30 of Set 9 | aligarh
# Processing Record 31 of Set 9 | tuy hoa
# Processing Record 32 of Set 9 | nantucket
# Processing Record 33 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 9 | ciudad bolivar
# Processing Record 35 of Set 9 | prescott
# Processing Record 36 of Set 9 | carinhanha
# Processing Record 37 of Set 9 | tecoanapa
# Processing Record 38 of Set 9 | ipatele
# Processing Record 39 of Set 9 | vanimo
# Processing Record 40 of Set 9 | belmonte
# Processing Record 41 of Set 9 | santa vitoria do palmar
# Processing Record 42 of Set 9 | jimani
# Processing Record 43 of Set 9 | inuvik
# Processing Record 44 of Set 9 | clyde river
# Processing Record 45 of Set 9 | cheyur
# City not found. Skipping...
# Processing Record 46 of Set 9 | talnakh
# Processing Record 47 of Set 9 | road town
# Processing Record 48 of Set 9 | gamba
# Processing Record 49 of Set 9 | pundaguitan
# Processing Record 50 of Set 9 | doka
# Processing Record 1 of Set 10 | kalemie
# Processing Record 2 of Set 10 | visby
# Processing Record 3 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 4 of Set 10 | zykovo
# Processing Record 5 of Set 10 | ituni
# City not found. Skipping...
# Processing Record 6 of Set 10 | kermanshah
# Processing Record 7 of Set 10 | mamit
# Processing Record 8 of Set 10 | cape canaveral
# Processing Record 9 of Set 10 | loubomo
# Processing Record 10 of Set 10 | hasaki
# Processing Record 11 of Set 10 | quatre cocos
# Processing Record 12 of Set 10 | zarate
# Processing Record 13 of Set 10 | chunhuhub
# Processing Record 14 of Set 10 | ahipara
# Processing Record 15 of Set 10 | asau
# Processing Record 16 of Set 10 | matagami
# Processing Record 17 of Set 10 | juneau
# Processing Record 18 of Set 10 | jalpan
# Processing Record 19 of Set 10 | carballo
# Processing Record 20 of Set 10 | adrar
# Processing Record 21 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 22 of Set 10 | phimai
# Processing Record 23 of Set 10 | fairbanks
# Processing Record 24 of Set 10 | tateyama
# Processing Record 25 of Set 10 | bousso
# Processing Record 26 of Set 10 | waling
# Processing Record 27 of Set 10 | camargo
# Processing Record 28 of Set 10 | eureka
# Processing Record 29 of Set 10 | hueyapan
# Processing Record 30 of Set 10 | mecca
# Processing Record 31 of Set 10 | ikongo
# Processing Record 32 of Set 10 | woodward
# Processing Record 33 of Set 10 | along
# Processing Record 34 of Set 10 | grand forks
# Processing Record 35 of Set 10 | north bend
# Processing Record 36 of Set 10 | college
# Processing Record 37 of Set 10 | san rafael del sur
# Processing Record 38 of Set 10 | rio brilhante
# Processing Record 39 of Set 10 | sibolga
# Processing Record 40 of Set 10 | taltal
# Processing Record 41 of Set 10 | curuca
# Processing Record 42 of Set 10 | arraias
# Processing Record 43 of Set 10 | cootamundra
# Processing Record 44 of Set 10 | cabedelo
# Processing Record 45 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 46 of Set 10 | katherine
# Processing Record 47 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 48 of Set 10 | grimshaw
# Processing Record 49 of Set 10 | gaya
# Processing Record 50 of Set 10 | okha
# Processing Record 1 of Set 11 | mareeba
# Processing Record 2 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 3 of Set 11 | ust-kuyga
# Processing Record 4 of Set 11 | axim
# Processing Record 5 of Set 11 | idah
# Processing Record 6 of Set 11 | abilene
# Processing Record 7 of Set 11 | kosai
# Processing Record 8 of Set 11 | isangel
# Processing Record 9 of Set 11 | evensk
# Processing Record 10 of Set 11 | theunissen
# Processing Record 11 of Set 11 | plaster rock
# Processing Record 12 of Set 11 | camana
# Processing Record 13 of Set 11 | puerto el triunfo
# Processing Record 14 of Set 11 | byron bay
# Processing Record 15 of Set 11 | hvide sande
# Processing Record 16 of Set 11 | los llanos de aridane
# Processing Record 17 of Set 11 | warmbad
# Processing Record 18 of Set 11 | boguchany
# Processing Record 19 of Set 11 | morondava
# Processing Record 20 of Set 11 | galesong
# Processing Record 21 of Set 11 | bernalillo
# Processing Record 22 of Set 11 | chancay
# Processing Record 23 of Set 11 | bosobolo
# Processing Record 24 of Set 11 | krasne
# Processing Record 25 of Set 11 | gergebil
# Processing Record 26 of Set 11 | poso
# Processing Record 27 of Set 11 | walvis bay
# Processing Record 28 of Set 11 | bathsheba
# Processing Record 29 of Set 11 | palmer
# Processing Record 30 of Set 11 | safranbolu
# Processing Record 31 of Set 11 | misrikh
# Processing Record 32 of Set 11 | hangu
# Processing Record 33 of Set 11 | acajutla
# Processing Record 34 of Set 11 | calatayud
# Processing Record 35 of Set 11 | kardla
# Processing Record 36 of Set 11 | ullapool
# Processing Record 37 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 11 | port macquarie
# Processing Record 39 of Set 11 | sampit
# Processing Record 40 of Set 11 | bayji
# Processing Record 41 of Set 11 | arona
# Processing Record 42 of Set 11 | berberati
# Processing Record 43 of Set 11 | tabarqah
# City not found. Skipping...
# Processing Record 44 of Set 11 | itoman
# Processing Record 45 of Set 11 | mutsamudu
# City not found. Skipping...
# Processing Record 46 of Set 11 | lower hutt
# Processing Record 47 of Set 11 | balkhash
# Processing Record 48 of Set 11 | amambai
# Processing Record 49 of Set 11 | bonavista
# Processing Record 50 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 1 of Set 12 | mashivka
# Processing Record 2 of Set 12 | aksarka
# Processing Record 3 of Set 12 | karratha
# Processing Record 4 of Set 12 | waingapu
# Processing Record 5 of Set 12 | ocean city
# Processing Record 6 of Set 12 | cockburn town
# Processing Record 7 of Set 12 | brigantine
# Processing Record 8 of Set 12 | jardim
# Processing Record 9 of Set 12 | kjollefjord
# Processing Record 10 of Set 12 | ereymentau
# Processing Record 11 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 12 | broome
# Processing Record 13 of Set 12 | roma
# Processing Record 14 of Set 12 | mumbwa
# Processing Record 15 of Set 12 | santiago del estero
# Processing Record 16 of Set 12 | boa vista
# Processing Record 17 of Set 12 | poum
# Processing Record 18 of Set 12 | kolokani
# Processing Record 19 of Set 12 | galesburg
# Processing Record 20 of Set 12 | santa lucia
# Processing Record 21 of Set 12 | lodja
# Processing Record 22 of Set 12 | tigil
# Processing Record 23 of Set 12 | vanersborg
# Processing Record 24 of Set 12 | takob
# City not found. Skipping...
# Processing Record 25 of Set 12 | machico
# Processing Record 26 of Set 12 | atbasar
# Processing Record 27 of Set 12 | mbandaka
# Processing Record 28 of Set 12 | skerries
# Processing Record 29 of Set 12 | kroderen
# City not found. Skipping...
# Processing Record 30 of Set 12 | conde
# Processing Record 31 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 32 of Set 12 | alice springs
# Processing Record 33 of Set 12 | ucluelet
# Processing Record 34 of Set 12 | kampot
# Processing Record 35 of Set 12 | xam nua
# Processing Record 36 of Set 12 | nelspruit
# Processing Record 37 of Set 12 | dovers
# Processing Record 38 of Set 12 | slave lake
# Processing Record 39 of Set 12 | arlit
# Processing Record 40 of Set 12 | ust-tsilma
# Processing Record 41 of Set 12 | outlook
# Processing Record 42 of Set 12 | ouadda
# Processing Record 43 of Set 12 | ponta do sol
# Processing Record 44 of Set 12 | scandiano
# Processing Record 45 of Set 12 | lyubeshiv
# City not found. Skipping...
# Processing Record 46 of Set 12 | carupano
# Processing Record 47 of Set 12 | kongoussi
# Processing Record 48 of Set 12 | chengde
# Processing Record 49 of Set 12 | upington
# Processing Record 50 of Set 12 | caravelas
# Processing Record 1 of Set 13 | wenling
# Processing Record 2 of Set 13 | scarborough
# Processing Record 3 of Set 13 | imbituba
# Processing Record 4 of Set 13 | puerto del rosario
# Processing Record 5 of Set 13 | sakaiminato
# Processing Record 6 of Set 13 | port-de-paix
# City not found. Skipping...
# Processing Record 7 of Set 13 | lincoln
# Processing Record 8 of Set 13 | minuri
# Processing Record 9 of Set 13 | sistranda
# Processing Record 10 of Set 13 | santa clara
# Processing Record 11 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 12 of Set 13 | fort nelson
# Processing Record 13 of Set 13 | victor harbor
# Processing Record 14 of Set 13 | puerto escondido
# Processing Record 15 of Set 13 | kuching
# Processing Record 16 of Set 13 | shumskiy
# Processing Record 17 of Set 13 | grindavik
# Processing Record 18 of Set 13 | svarychiv
# Processing Record 19 of Set 13 | tripoli
# Processing Record 20 of Set 13 | labuan
# Processing Record 21 of Set 13 | sovetskiy
# Processing Record 22 of Set 13 | ambodifototra
# City not found. Skipping...
# Processing Record 23 of Set 13 | quang ngai
# Processing Record 24 of Set 13 | sande
# Processing Record 25 of Set 13 | beringovskiy
# Processing Record 26 of Set 13 | comodoro rivadavia
# Processing Record 27 of Set 13 | bossangoa
# Processing Record 28 of Set 13 | rawlins
# Processing Record 29 of Set 13 | sur
# Processing Record 30 of Set 13 | matay
# Processing Record 31 of Set 13 | murdochville
# Processing Record 32 of Set 13 | nagato
# Processing Record 33 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 34 of Set 13 | nizwa
# Processing Record 35 of Set 13 | isla mujeres
# Processing Record 36 of Set 13 | babstovo
# Processing Record 37 of Set 13 | calama
# Processing Record 38 of Set 13 | borup
# Processing Record 39 of Set 13 | shimoda
# Processing Record 40 of Set 13 | husavik
# Processing Record 41 of Set 13 | lagoa formosa
# Processing Record 42 of Set 13 | praia da vitoria
# Processing Record 43 of Set 13 | inhambane
# Processing Record 44 of Set 13 | ponnani
# Processing Record 45 of Set 13 | aleksandriya
# Processing Record 46 of Set 13 | aksum
# Processing Record 47 of Set 13 | elmadag
# Processing Record 48 of Set 13 | mersing
# Processing Record 49 of Set 13 | praya
# Processing Record 50 of Set 13 | idrinskoye
# Processing Record 1 of Set 14 | kirakira
# Processing Record 2 of Set 14 | djambala
# Processing Record 3 of Set 14 | cassilandia
# Processing Record 4 of Set 14 | lohja
# Processing Record 5 of Set 14 | mandiana
# Processing Record 6 of Set 14 | kabo
# Processing Record 7 of Set 14 | saint-augustin
# Processing Record 8 of Set 14 | upernavik
# Processing Record 9 of Set 14 | miri
# Processing Record 10 of Set 14 | shuya
# Processing Record 11 of Set 14 | san juan
# Processing Record 12 of Set 14 | maunabo
# Processing Record 13 of Set 14 | sangar
# Processing Record 14 of Set 14 | moron
# Processing Record 15 of Set 14 | newnan
# Processing Record 16 of Set 14 | antofagasta
# Processing Record 17 of Set 14 | manavgat
# Processing Record 18 of Set 14 | belogorsk
# Processing Record 19 of Set 14 | bilma
# Processing Record 20 of Set 14 | puerto colombia
# Processing Record 21 of Set 14 | teguldet
# Processing Record 22 of Set 14 | cordoba
# Processing Record 23 of Set 14 | pasighat
# Processing Record 24 of Set 14 | ponta delgada
# Processing Record 25 of Set 14 | egvekinot
# Processing Record 26 of Set 14 | mykhaylivka
# Processing Record 27 of Set 14 | aksay
# Processing Record 28 of Set 14 | bonfim
# Processing Record 29 of Set 14 | solano
# Processing Record 30 of Set 14 | boldumsaz
# Processing Record 31 of Set 14 | stettler
# Processing Record 32 of Set 14 | mazatlan
# Processing Record 33 of Set 14 | montrose
# Processing Record 34 of Set 14 | bretigny-sur-orge
# Processing Record 35 of Set 14 | honningsvag
# Processing Record 36 of Set 14 | solnechnyy
# Processing Record 37 of Set 14 | pangody
# Processing Record 38 of Set 14 | burica
# City not found. Skipping...
# Processing Record 39 of Set 14 | lazaro cardenas
# Processing Record 40 of Set 14 | reconquista
# Processing Record 41 of Set 14 | nishihara
# Processing Record 42 of Set 14 | makakilo city
# Processing Record 43 of Set 14 | kashi
# Processing Record 44 of Set 14 | rehoboth
# Processing Record 45 of Set 14 | cuamba
# Processing Record 46 of Set 14 | ayagoz
# Processing Record 47 of Set 14 | panlaitan
# Processing Record 48 of Set 14 | andenes
# Processing Record 49 of Set 14 | adjumani
# Processing Record 50 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 15 | gravdal
# Processing Record 2 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 3 of Set 15 | rawson
# Processing Record 4 of Set 15 | karpathos
# Processing Record 5 of Set 15 | isabela
# Processing Record 6 of Set 15 | mansa
# Processing Record 7 of Set 15 | ambilobe
# Processing Record 8 of Set 15 | icod de los vinos
# Processing Record 9 of Set 15 | irbeyskoye
# Processing Record 10 of Set 15 | colon
# Processing Record 11 of Set 15 | guntakal
# Processing Record 12 of Set 15 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 13 of Set 15 | constantine
# Processing Record 14 of Set 15 | brae
# Processing Record 15 of Set 15 | dongdu
# Processing Record 16 of Set 15 | waipawa
# Processing Record 17 of Set 15 | knysna
# Processing Record 18 of Set 15 | makung
# City not found. Skipping...
# Processing Record 19 of Set 15 | fonte boa
# Processing Record 20 of Set 15 | nuuk
# Processing Record 21 of Set 15 | ostrov
# Processing Record 22 of Set 15 | chojnow
# Processing Record 23 of Set 15 | poplar bluff
# Processing Record 24 of Set 15 | prince rupert
# Processing Record 25 of Set 15 | sumenep
# Processing Record 26 of Set 15 | igarka
# Processing Record 27 of Set 15 | hirara
# Processing Record 28 of Set 15 | grand-santi
# Processing Record 29 of Set 15 | lensk
# Processing Record 30 of Set 15 | hurghada
# Processing Record 31 of Set 15 | crotone
# Processing Record 32 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 33 of Set 15 | puerto leguizamo
# Processing Record 34 of Set 15 | khorixas
# Processing Record 35 of Set 15 | katima mulilo
# Processing Record 36 of Set 15 | listowel
# Processing Record 37 of Set 15 | gold coast
# Processing Record 38 of Set 15 | ossora
# Processing Record 39 of Set 15 | huron
# Processing Record 40 of Set 15 | urumqi
# Processing Record 41 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 42 of Set 15 | kangundo
# Processing Record 43 of Set 15 | creel
# Processing Record 44 of Set 15 | takaka
# Processing Record 45 of Set 15 | chhabra
# Processing Record 46 of Set 15 | nemuro
# Processing Record 47 of Set 15 | manglaur
# Processing Record 48 of Set 15 | atherton
# Processing Record 49 of Set 15 | iwanai
# Processing Record 50 of Set 15 | svetlogorsk
# Processing Record 1 of Set 16 | kot diji
# Processing Record 2 of Set 16 | marevo
# Processing Record 3 of Set 16 | christchurch
# Processing Record 4 of Set 16 | henties bay
# Processing Record 5 of Set 16 | mogwase
# Processing Record 6 of Set 16 | warrnambool
# Processing Record 7 of Set 16 | homa bay
# Processing Record 8 of Set 16 | lloydminster
# Processing Record 9 of Set 16 | manicore
# Processing Record 10 of Set 16 | chimoio
# Processing Record 11 of Set 16 | baiyin
# Processing Record 12 of Set 16 | san patricio
# Processing Record 13 of Set 16 | hluti
# Processing Record 14 of Set 16 | maniitsoq
# Processing Record 15 of Set 16 | vestmanna
# Processing Record 16 of Set 16 | casas grandes
# Processing Record 17 of Set 16 | norman
# Processing Record 18 of Set 16 | khatanga
# Processing Record 19 of Set 16 | jedrzejow
# Processing Record 20 of Set 16 | salekhard
# Processing Record 21 of Set 16 | pilot butte
# Processing Record 22 of Set 16 | vega de alatorre
# Processing Record 23 of Set 16 | wangaratta
# Processing Record 24 of Set 16 | karonga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 709

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Hermanus -34.4187   19.2345     63.81        62           0
# 1              Albany  42.6001  -73.9662     57.94        36          14
# 2          Nikolskoye  59.7035   30.7861     39.09        95          81
# 3               Keffi   8.8486    7.8736     90.50        34          48
# 4            Luderitz -26.6481   15.1594     70.56        56           3
# 5            Cherskiy  68.7500  161.3000    -11.29        98          99
# 6            Yar-Sale  66.8333   70.8333     34.47       100         100
# 7      Cuajinicuilapa  16.4667  -98.4167     94.37        36          48
# 8             Mataura -46.1927  168.8643     48.47        99         100
# 9  La Baule-Escoublac  47.2922   -2.3640     67.66        56           0
#
#    Wind Speed Country Current Description                 Date
# 0        3.58      ZA           clear sky  2022-04-11 17:59:15
# 1        4.18      US          few clouds  2022-04-11 17:57:58
# 2        2.98      RU       broken clouds  2022-04-11 17:59:16
# 3        5.61      NG    scattered clouds  2022-04-11 17:59:16
# 4        4.25      NA           clear sky  2022-04-11 17:59:17
# 5        7.07      RU     overcast clouds  2022-04-11 17:59:17
# 6       11.70      RU     overcast clouds  2022-04-11 17:59:18
# 7       10.76      MX    scattered clouds  2022-04-11 17:59:18
# 8        1.43      NZ       moderate rain  2022-04-11 17:59:19
# 9        6.91      FR           clear sky  2022-04-11 17:59:19

# %%
# Convert the order of the columns in the DataFrame to be in the following 
# order: City, Country, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed
# & Current Description.
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp","Humidity", 
                    "Cloudiness", "Wind Speed", "Current Description"]
# Assign city_data_df = city_data_df[new_column_order]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Hermanus      ZA -34.4187   19.2345     63.81        62
# 1              Albany      US  42.6001  -73.9662     57.94        36
# 2          Nikolskoye      RU  59.7035   30.7861     39.09        95
# 3               Keffi      NG   8.8486    7.8736     90.50        34
# 4            Luderitz      NA -26.6481   15.1594     70.56        56
# 5            Cherskiy      RU  68.7500  161.3000    -11.29        98
# 6            Yar-Sale      RU  66.8333   70.8333     34.47       100
# 7      Cuajinicuilapa      MX  16.4667  -98.4167     94.37        36
# 8             Mataura      NZ -46.1927  168.8643     48.47        99
# 9  La Baule-Escoublac      FR  47.2922   -2.3640     67.66        56
#
#    Cloudiness  Wind Speed Current Description
# 0           0        3.58           clear sky
# 1          14        4.18          few clouds
# 2          81        2.98       broken clouds
# 3          48        5.61    scattered clouds
# 4           3        4.25           clear sky
# 5          99        7.07     overcast clouds
# 6         100       11.70     overcast clouds
# 7          48       10.76    scattered clouds
# 8         100        1.43       moderate rain
# 9           0        6.91           clear sky

# %%
# Create the output file (CSV).
output_data_file = (r"C:\Users\izee\OneDrive\Desktop\Data Analysis and Visualization\Module 6 - WeatherPy with Python APIs\World_Weather_Analysis\Weather_Database\WeatherPy_Database.csv")
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
